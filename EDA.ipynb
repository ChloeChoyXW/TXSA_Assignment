# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from collections import Counter
#from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

# %%
df = pd.read_csv('joined_cyberbullying_tweet.csv')
df.shape
# Out:
# (43765, 2)

# %%
df['cyberbullying_type'] = df['cyberbullying_type'].astype(str)
df['tweet_text'] = df['tweet_text'].astype(str)

# %%
categories = df['cyberbullying_type'].unique()
categories#[0]
# Out:
# array(['not_cyberbullying', 'gender', 'religion', 'other_cyberbullying',
#        'age', 'ethnicity'], dtype=object)

# %%
word_string=" ".join(df['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Overall Word Cloud")
plt.show()

# %%
# Count of Target Variable
categories = df['cyberbullying_type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(categories, labels=categories.index, autopct='%1.1f%%', startangle=140)
#plt.pie(categories, labels=categories.index, autopct=lambda pct: f"{pct:.0f}({sum(categories)*pct/100:.0f})", startangle=140)
plt.title('Percentage of Each Class in Cyberbullying Type')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# Word Cloud by target variable

# %%
# not_cyberbullying
word_string=" ".join(df[df['cyberbullying_type'] == 'not_cyberbullying']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Non Cyberbully")
plt.show()

# %%
# Gender
word_string=" ".join(df[df['cyberbullying_type'] == 'gender']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Gender Type Cyberbully",fontsize=25)
plt.show()

# %%
# Religion
word_string=" ".join(df[df['cyberbullying_type'] == 'religion']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300,  
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Religion Type Cyberbully",fontsize=25)
plt.show()

# %%
# Age
word_string=" ".join(df[df['cyberbullying_type'] == 'age']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Age Type Cyberbully",fontsize=25)
plt.show()

# %%
# ethnicity
word_string=" ".join(df[df['cyberbullying_type'] == 'ethnicity']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300,
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Ethnicity Type Cyberbully",fontsize=25)
plt.show()

# %%
# other_cyberbullying
word_string=" ".join(df[df['cyberbullying_type'] == 'other_cyberbullying']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300,
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Others type Cyberbullying",fontsize=25)
plt.show()

# %%
df['tokens'] = df['tweet_text'].apply(word_tokenize)
df
# Out:
#                                               tweet_text cyberbullying_type  \
# 0                                         word food crap  not_cyberbullying
# 1                                                  white  not_cyberbullying
# 2                        classy whore red velvet cupcake  not_cyberbullying
# 3                               account account like lie  not_cyberbullying
# 4      yes test god good bad different weird whatever...  not_cyberbullying
# ...                                                  ...                ...
# 43760               shut dumb acting like nagging nigger          ethnicity
# 43761  black people anything anything yet free partic...          ethnicity
# 43762  turner withhold disappointment turner court ab...          ethnicity
# 43763  swear god dumb nigger bitch got bleach hair al...          ethnicity
# 43764                got chill dog dumb nigger bitch mao          ethnicity
#
#                                                   tokens
# ...

# %%
all_tokens = [token for sublist in df['tokens'] for token in sublist]
word_counts = Counter(all_tokens)
top_20_words = word_counts.most_common(20)
words, frequencies = zip(*top_20_words)

plt.figure(figsize=(10, 8))
plt.barh(words, frequencies, color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.title('Top 20 Most Frequent Words')
plt.gca().invert_yaxis()  # Invert y-axis to have the most frequent word on top
plt.show()

# %%
df['word_length'] = df['tokens'].apply(lambda x: len(x))
df
# Out:
#                                               tweet_text cyberbullying_type  \
# 0                                         word food crap  not_cyberbullying
# 1                                                  white  not_cyberbullying
# 2                        classy whore red velvet cupcake  not_cyberbullying
# 3                               account account like lie  not_cyberbullying
# 4      yes test god good bad different weird whatever...  not_cyberbullying
# ...                                                  ...                ...
# 43760               shut dumb acting like nagging nigger          ethnicity
# 43761  black people anything anything yet free partic...          ethnicity
# 43762  turner withhold disappointment turner court ab...          ethnicity
# 43763  swear god dumb nigger bitch got bleach hair al...          ethnicity
# 43764                got chill dog dumb nigger bitch mao          ethnicity
#
# ...

# %%
# Word length of tweets

plt.figure(figsize=(15,8))
ax = sns.countplot(x=df['word_length'], palette='mako')
plt.title('Length of Words in Tweets', fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('Length of Words')
plt.show()

# %%
less_than_10_words = df[df['word_length'] < 10]
less_than_10_words['word_length'].value_counts()
# Out:
# 7    3156
# 8    3105
# 9    3067
# 6    3062
# 5    2813
# 4    2625
# 3    1862
# 2    1214
# 1     549
# Name: word_length, dtype: int64

# %%
#less_than_10_words = df[df['word_length'] < 10]

plt.figure(figsize=(7,5))
ax = sns.countplot(x='word_length', data=df[df['word_length']<10], palette='mako')
plt.title('Count of tweets with less than 10 words', fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.show()

# %%
# Num of Characters per Sentence

# %%
# Word Frequency of Top 10 Words
