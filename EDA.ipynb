# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from collections import Counter
#from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

# %%
df = pd.read_csv('new_cyberbully_tweet.csv')

# %%
import wordninja
# df['tweet_text'] = df['tweet_text'].apply(lambda x: ' '.join(wordninja.split(x)))
# df.head(10)  
text = ""

# Split concatenated words using Wordninja
split_words = ' '.join(wordninja.split(text))

print(split_words)
# Out:
# X och it lSu c kkk s

# %%
import re

def normalize_repeating_characters(text):
    # Use regular expression to replace consecutive repeating characters occurring at least three times with a single occurrence
    normalized_text = re.sub(r'(.)\1{2,}', r'\1\1', text)
    return normalized_text

# Example text with repeating characters
text = "I loooooove mommmmmm sooo muchhhh" 

# Normalize repeating characters
normalized_text = normalize_repeating_characters(text)

print(normalized_text)

# %%
df['cyberbullying_type'] = df['cyberbullying_type'].astype(str)
df['tweet_text'] = df['tweet_text'].astype(str)

# %%
categories = df['cyberbullying_type'].unique()
categories#[0]
# Out:
# array(['not_cyberbullying', 'gender', 'religion', 'other_cyberbullying',
#        'age', 'ethnicity'], dtype=object)

# %%
word_string=" ".join(df['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, stopwords = None, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Overall Word Cloud")
plt.show()

# %%
# Count of Target Variable
categories = df['cyberbullying_type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(categories, labels=categories.index, autopct='%1.1f%%', startangle=140)
#plt.pie(categories, labels=categories.index, autopct=lambda pct: f"{pct:.0f}({sum(categories)*pct/100:.0f})", startangle=140)
plt.title('Percentage of Each Class in Cyberbullying Type')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# Word Cloud by target variable

# %%
# not_cyberbullying
word_string=" ".join(df[df['cyberbullying_type'] == 'not_cyberbullying']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, stopwords = None, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Non Cyberbully")
plt.show()

# %%
# Gender
word_string=" ".join(df[df['cyberbullying_type'] == 'gender']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, stopwords = None, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Gender Type Cyberbully",fontsize=25)
plt.show()

# %%
# Religion
word_string=" ".join(df[df['cyberbullying_type'] == 'religion']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, stopwords = None, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Religion Type Cyberbully",fontsize=25)
plt.show()

# %%
# Age
word_string=" ".join(df[df['cyberbullying_type'] == 'age']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, stopwords = None, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Age Type Cyberbully",fontsize=25)
plt.show()

# %%
# ethnicity
word_string=" ".join(df[df['cyberbullying_type'] == 'ethnicity']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, stopwords = None, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Ethnicity Type Cyberbully",fontsize=25)
plt.show()

# %%
# other_cyberbullying
word_string=" ".join(df[df['cyberbullying_type'] == 'other_cyberbullying']['tweet_text'])
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size= 300, stopwords = None, 
                      width=1400, height=800).generate(word_string)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title(f"Word Cloud for Others type Cyberbullying",fontsize=25)
plt.show()

# %%
all_words = ' '.join(df['tweet_text']).lower()  # Join all text data into one string
tokens = word_tokenize(all_words)

word_counts = Counter(tokens)
top_words = word_counts.most_common(20)

plt.figure(figsize=(10, 8))
words, counts = zip(*top_words)
plt.barh(range(len(words)), counts, align='center', alpha=0.7)
plt.yticks(range(len(words)), words)
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top 20 Most Frequent Words')
plt.gca().invert_yaxis()  # Invert y-axis to have the most frequent words at the top
plt.show()

# %%
# Length of various tweet texts
df['tweet_token'] = df['tweet_text'].apply(word_tokenize)
text_len = []
for text in df.tweet_token:
    tweet_len = len(text)
    text_len.append(tweet_len)
df['text_len'] = text_len

plt.figure(figsize=(15,8))
ax = sns.countplot(x='text_len', data=df, palette='mako')
plt.title('Count of words in tweets', fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %%
# Num of Characters per Sentence

# %%
# Word Frequency of Top 10 Words

# %%
df.groupby('cyberbullying_type').describe()
# Out:
#                     tweet_text         \
#                          count unique
# cyberbullying_type
# age                       7992   7966
# ethnicity                 7959   7939
# gender                    7822   7643
# not_cyberbullying         6428   6323
# other_cyberbullying       7823   7701
# religion                  7993   7969
#
#
#                                                                    top freq
# cyberbullying_type
# age                  Mom brutally attacked by teen girls outside CA...   14
# ethnicity                        tayyoung_ FUCK OBAMA, dumb ass nigger   11
# gender                 Miley Cyrus makes date rape joke onstage at GAY   30
# not_cyberbullying                                                  nan   47
# other_cyberbullying                                                nan  109
# religion                    MaxBlumenthal Islamophobia - fear of this.    5
